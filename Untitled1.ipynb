# %%
import yt_dlp
from IPython.display import display, YouTubeVideo

def fetch_animated_videos(topic, num_videos=3):
    search_query = f"ytsearch{num_videos}:{topic} animation explained"
    ydl_opts = {
        "quiet": True,
        "extract_flat": True,
        "force_generic_extractor": True
    }
    
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(search_query, download=False)
        
        if "entries" in info:
            for video in info["entries"]:
                if video.get("duration", 301) <= 300:  # Only include videos <= 5 minutes
                    video_id = video["id"]
                    print(f"Title: {video['title']}")
                    print(f"URL: {video['url']}\n")
                    display(YouTubeVideo(video_id))

# Example usage
fetch_animated_videos("Newton's Laws of Motion", num_videos=2)
# Out:
# Title: Newton's 3 Laws, with a bicycle - Joshua Manley
# URL: https://www.youtube.com/watch?v=JGO_zDWmkvk

# %%
# !pip install yt-dlp
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 6.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
