# %%
import edge_tts

# Jupyter-specific async handling
async def text_to_speech():
    communicate = edge_tts.Communicate(
        text="This works in Jupyter!", 
        voice="en-US-ChristopherNeural"
    )
    await communicate.save("a.mp3")

# Use this instead of asyncio.run()
await text_to_speech()  # Directly await in Jupyter cell

# %%
import edge_tts

# Jupyter-specific async handling
async def text_to_speech():
    communicate = edge_tts.Communicate(
        text=""" Introduction... [PAUSE]... [PAUSE]     "Have you ever wondered why magnets can pull paper clips through a tablecloth, even when they're not touching? It's as if the magnet's power is reaching out to grab them, and that's exactly what's happening 1. but how?"  
    Today, we're exploring the fascinating world of MAGNETIC FIELD AND FIELD LINES! 🔍  
    Quick prediction: What do you think happens when...? (We'll find out!)
    ... [PAUSE]     📚 Explanation... [PAUSE]
Dynamic Lesson on Magnetic Field and Field Lines... [PAUSE] Step 1: Engaging Start... [PAUSE] Imagine you're on a treasure hunt, and you have a map that leads you to a mysterious location. As you approach the location, you notice that your compass starts to behave strangely, pointing in different directions. What could be causing this phenomenon?... [PAUSE] Step 2: Introduce a Video... [PAUSE] Watch the following video that demonstrates the effect of a bar magnet on a compass needle:... [PAUSE] Next, we\'ll watch a video showing Compass Needle and Bar Magnet Interaction... [PAUSE]... [PAUSE] Before watching, predict what will happen when the compass needle is brought near the bar magnet. Write down your predictions.... [PAUSE] Step 3: Explain the Concept... [PAUSE] Magnetic Field and Field Lines... [PAUSE] * A magnetic field is a region around a magnet where the force of the magnet can be detected.
* Magnetic field lines are imaginary lines that emerge from the north pole and merge at the south pole of a magnet.
* The direction of the magnetic field is taken to be the direction in which a north pole of a compass needle moves inside it.
* The relative strength of the magnetic field is shown by the degree of closeness of the field lines.
* No two field lines cross each other.... [PAUSE] Activity 13.2: Iron Filings and Magnetic Field Lines... [PAUSE] * Fix a sheet of white paper on a drawing board using adhesive material.
* Place a bar magnet in the center of the paper.
* Sprinkle iron filings uniformly around the bar magnet.
* Tap the board gently.
* Observe the pattern formed by the iron filings.... [PAUSE] Step 4: Critical Thinking... [PAUSE] * Why do you think the iron filings arrange themselves in a specific pattern around the bar magnet?
* How does the magnetic field of a bar magnet interact with the compass needle?
* Can you think of any real-life applications where understanding magnetic fields and field lines is crucial?... [PAUSE] Additional Activities... [PAUSE] * Draw the magnetic field lines around a bar magnet using a compass and paper.
* Explore how the strength of the magnetic field changes with distance from the magnet.
* Research and present on a real-life application of magnetic fields, such as magnetic resonance imaging (MRI) or magnetic levitation trains.... [PAUSE] By the end of this lesson, students will have a deeper understanding of magnetic fields and field lines, and how they interact with compass needles and other magnets.... [PAUSE]     🔑 Key Takeaways... [PAUSE]
Here are the key points about magnetic fields and field lines for 8th graders:... [PAUSE] 1. [PAUSE] IMPORTANT CONCEPT... A magnetic field is a region around a magnet where the magnetic force can be detected, and it is represented by magnetic field lines that emerge from the north pole and enter the south pole of a magnet.
1. [PAUSE] REAL WORLD EXAMPLE... The Earth's magnetic field is what causes a compass needle to deflect, allowing it to point towards the north direction, which is essential for navigation.
1. Equation: Not applicable in this case.
1. [PAUSE] FUN FACT... The pattern of iron filings around a bar magnet, as seen in Activity 13.2, is a visual representation of the magnetic field lines, and it helps us understand the direction and strength of the magnetic field.
    """
, 
        voice="hi-IN-SwaraNeural",
        pitch="-10Hz",
        
        volume="+100%"
    )
    await communicate.save("output.mp3")

# Use this instead of asyncio.run()
await text_to_speech()  # Directly await in Jupyter cell

# %%
import edge_tts

# Jupyter-specific async handling
async def text_to_speech():
    communicate = edge_tts.Communicate(
        text="""**Introduction:**

    Imagine you're standing next to a long electric wire carrying current. You might wonder: 
    Does this wire have any effect on the space around it? Well, just like a magnet creates 
    a magnetic field, an electric current does the same! 
    
    Scientists discovered a simple way to figure out the direction of this magnetic field, 
    and it's called the Right-Hand Thumb Rule.
    

**AI Explanation:**
Let's Dive into the World of Magnets!

Imagine you're a superhero with the power to control magnets. You're on a mission to save the city from evil robots that are disrupting the magnetic fields around the city's power lines. But, how do you know which direction the magnetic field is flowing?

That's where the Right-Hand Thumb Rule comes in! It's a simple trick to help you figure out the direction of the magnetic field around a current-carrying conductor.

Let's watch a video to get a better understanding of this concept:

"""
, 
        voice="hi-IN-SwaraNeural",
        pitch="-10Hz",
        
        volume="+100%"
    )
    await communicate.save("test3.mp3")

# Use this instead of asyncio.run()
await text_to_speech()  # Directly await in Jupyter cell
